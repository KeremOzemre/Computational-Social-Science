# %% [markdown]
# ### __Week 8__

# %% [markdown]
# #### Loading the Network Graph

# %%
import pickle
import networkx as nx
import pandas as pd
import ast
from collections import Counter
import numpy as np

with open("network/G_social_compute.pkl", "rb") as f:
    G_social_compute = pickle.load(f)

tokenized_abstract = pd.read_csv('/Users/keremozemre/Library/CloudStorage/OneDrive-DanmarksTekniskeUniversitet/social compute/Computational-Social-Science/tokenized_abstract.csv')
papers_dataset = pd.read_csv("/Users/keremozemre/Library/CloudStorage/OneDrive-DanmarksTekniskeUniversitet/social compute/Computational-Social-Science/more_than_one_author_papers_dataset.csv")
papers_dataset["author_ids"] = papers_dataset["author_ids"].apply(ast.literal_eval)

# %%
tokenized_abstract
# Out:
#                                       id  \
# 0       https://openalex.org/W1999649023
# 1       https://openalex.org/W2055957857
# 2       https://openalex.org/W3121315632
# 3       https://openalex.org/W2002781392
# 4       https://openalex.org/W2885869279
# ...                                  ...
# 167394  https://openalex.org/W2188156563
# 167395  https://openalex.org/W2915560807
# 167396  https://openalex.org/W4387301543
# 167397  https://openalex.org/W2945142372
# 167398  https://openalex.org/W2754997359
#
#                                                     title  \
# 0                   Statistical Methods for Meta-Analysis
# 1                    Framing as a Theory of Media Effects
# 2                        What Makes Online Content Viral?
# 3       Framing, Agenda Setting, and Priming: The Evol...
# 4       How to Do a Systematic Review: A Best Practice...
# ...                                                   ...
# 167394  Predictability of Equity Returns over Differen...
# 167395  Understanding the Athena SWAN award scheme for...
# 167396  A Large Language Model-Based Generative Natura...
# 167397  Facebook-based social support and health: A sy...
# 167398  Recommendations for male-friendly individual c...
#
#                                            abstract_index  \
# 0       {'Preface.': [0], 'Introduction.': [1], 'Data'...
# 1       {'Research': [0], 'on': [1], 'framing': [2, 25...
# 2       {'Why': [0], 'are': [1, 129], 'certain': [2], ...
# 3       {'This': [0], 'special': [1], 'issue': [2], 'o...
# 4       {'Systematic': [0], 'reviews': [1, 54, 133, 15...
# ...                                                   ...
# 167394                                                NaN
# 167395  {'Abstract': [0], 'Background': [1], 'Given': ...
# 167396  {'Abstract': [0], 'Background': [1], 'Headache...
# 167397  {'The': [0], 'rise': [1], 'of': [2, 34, 48, 55...
# 167398  {'Over': [0], 'the': [1, 19, 121], 'past': [2]...
#
#                                                      text  \
# 0       Preface. Introduction. Data Sets. Tests of Sta...
# 1       Research on framing is characterized by theore...
# 2       Why are certain pieces of online content (e.g....
# 3       This special issue of Journal of Communication...
# 4       Systematic reviews are characterized by a meth...
# ...                                                   ...
# 167394                                                NaN
# 167395  Abstract Background Given that the complex mix...
# 167396  Abstract Background Headache frequency, define...
# 167397  The rise of social networking sites (SNSs) hav...
# 167398  Over the past few decades, there have been cal...
#
#                                                    tokens
# 0       ['preface', 'introduction', 'data', 'sets', 't...
# 1       ['research', 'framing', 'characterized', 'theo...
# 2       ['certain', 'pieces', 'online', 'content_eg', ...
# 3       ['special', 'issue', 'journal', 'communication...
# 4       ['systematic', 'reviews', 'characterized', 'me...
# ...                                                   ...
# 167394                                                NaN
# 167395  ['abstract_background', 'given', 'complex', 'm...
# 167396  ['abstract_background', 'headache', 'frequency...
# 167397  ['rise_social', 'networking', 'sites', 'snss',...
# 167398  ['past', 'decades', 'calls', 'customize', 'the...
#
# [167399 rows x 5 columns]

# %%
louvain_social_compute = nx.community.louvain_communities(G_social_compute,seed = 100)
social_compute_louvain_communities_size = {}
for i,community in enumerate(louvain_social_compute):
    social_compute_louvain_communities_size[i] = len(community)
social_compute_louvain_communities_size
# Out:
# {0: 362,
#  1: 361,
#  2: 98,
#  3: 3,
#  4: 318,
#  5: 843,
#  6: 494,
#  7: 355,
#  8: 32,
#  9: 5,
#  10: 262,
#  11: 10,
#  12: 8,
#  13: 3,
#  14: 12,
#  15: 345,
#  16: 140,
#  17: 319,
#  18: 4,
#  19: 13,
#  20: 380,
#  21: 7,
#  22: 5,
#  23: 10,
#  24: 3,
#  25: 146,
#  26: 287,
#  27: 3,
#  28: 22,
#  29: 4,
#  30: 61,
#  31: 227,
#  32: 19,
#  33: 34,
#  34: 208,
#  35: 2,
#  36: 13,
#  37: 51,
#  38: 3,
#  39: 2,
#  40: 21,
#  41: 152,
#  42: 6,
#  43: 106,
#  44: 8,
#  45: 122,
#  46: 3,
#  47: 432,
#  48: 267,
#  49: 6,
#  50: 10,
#  51: 86,
#  52: 161,
#  53: 3,
#  54: 738,
#  55: 133,
#  56: 5,
#  57: 7,
#  58: 32,
#  59: 6,
#  60: 4,
#  61: 138,
#  62: 400,
#  63: 11,
#  64: 7,
#  65: 5,
#  66: 7,
#  67: 338,
#  68: 5,
#  69: 6,
#  70: 5,
#  71: 3,
#  72: 7,
#  73: 4,
#  74: 116,
#  75: 88,
#  76: 6,
#  77: 8,
#  78: 7,
#  79: 13,
#  80: 5,
#  81: 6,
#  82: 7,
#  83: 3,
#  84: 276,
#  85: 1306,
#  86: 173,
#  87: 42,
#  88: 5,
#  89: 10,
#  90: 7,
#  91: 8,
#  92: 270,
#  93: 3,
#  94: 6,
#  95: 36,
#  96: 28,
#  97: 119,
#  98: 5,
#  99: 5,
#  100: 2,
#  101: 33,
#  102: 7,
#  103: 8,
#  104: 2,
#  105: 179,
#  106: 11,
#  107: 4,
#  108: 56,
#  109: 3,
#  110: 9,
#  111: 181,
#  112: 174,
#  113: 4,
#  114: 7,
#  115: 369,
#  116: 6,
#  117: 5,
#  118: 26,
#  119: 85,
#  120: 183,
#  121: 194,
#  122: 197,
#  123: 17,
#  124: 12,
#  125: 92,
#  126: 3,
#  127: 11,
#  128: 30,
#  129: 6,
#  130: 67,
#  131: 230,
#  132: 52,
#  133: 10,
#  134: 8,
#  135: 9,
#  136: 37,
#  137: 5,
#  138: 5,
#  139: 7,
#  140: 4,
#  141: 6,
#  142: 2,
#  143: 2,
#  144: 362,
#  145: 20,
#  146: 14,
#  147: 10,
#  148: 5,
#  149: 4,
#  150: 59,
#  151: 536,
#  152: 6,
#  153: 120,
#  154: 23,
#  155: 4,
#  156: 7,
#  157: 13,
#  158: 7,
#  159: 3,
#  160: 4,
#  161: 240,
#  162: 272,
#  163: 2,
#  164: 4,
#  165: 2,
#  166: 298,
#  167: 55,
#  168: 8,
#  169: 2,
#  170: 4,
#  171: 31,
#  172: 5,
#  173: 340,
#  174: 110,
#  175: 8,
#  176: 7,
#  177: 18,
#  178: 10,
#  179: 19,
#  180: 4,
#  181: 91,
#  182: 3,
#  183: 9,
#  184: 7,
#  185: 5,
#  186: 9,
#  187: 14,
#  188: 2,
#  189: 19,
#  190: 1043,
#  191: 5,
#  192: 2,
#  193: 9,
#  194: 19,
#  195: 16,
#  196: 5,
#  197: 4,
#  198: 22,
#  199: 7,
#  200: 8,
#  201: 31,
#  202: 9,
#  203: 122,
#  204: 4,
#  205: 9,
#  206: 215,
#  207: 44,
#  208: 9,
#  209: 7,
#  210: 4,
#  211: 20,
#  212: 6,
#  213: 107,
#  214: 3,
#  215: 5,
#  216: 40,
#  217: 4,
#  218: 17,
#  219: 3,
#  220: 2,
#  221: 2,
#  222: 23,
#  223: 238,
#  224: 6,
#  225: 7,
#  226: 281,
#  227: 100,
#  228: 23}

# %%
for community_id, community_nodes in enumerate(louvain_social_compute):
    for node in community_nodes:
        G_social_compute.nodes[node]['community'] = community_id

for node, deg in G_social_compute.degree():
    G_social_compute.nodes[node]['degree'] = deg

# %% [markdown]
# ### Checking if the assignment is correct

# %%
G_social_compute.nodes['https://openalex.org/A5013693751']
# Out:
# {'display_name': 'Ingram Olkin',
#  'country': 'US',
#  'first_publication_year': 1988,
#  'total_citations': 13344,
#  'community': 26,
#  'degree': 3}

# %%
import ast
import pandas as pd

def abstracts_for_community_id(community_id):
    G = G_social_compute
    
    # Step 1: get authors in the community
    authors_in_community = [
        node for node in G.nodes if G.nodes[node]["community"] == community_id
    ]
    print(f"Number of authors in community {community_id}: {len(authors_in_community)}")
    
    # Step 2: filter papers that contain at least one author from the community
    papers = papers_dataset[
        papers_dataset["author_ids"].apply(lambda authors: any(a in authors_in_community for a in authors))
    ]
    print(f"Number of papers in community {community_id}: {len(papers)}")
    
    # Step 3: select tokenized abstracts for these papers
    tokens_series = tokenized_abstract.loc[
        tokenized_abstract["id"].isin(papers["id"]) &
        tokenized_abstract["tokens"].notna() &
        (tokenized_abstract["tokens"].str.len() > 0),
        "tokens"
    ]
    
    # Step 4: efficiently convert string-lists to real lists and flatten
    
    token_list = tokens_series.apply(ast.literal_eval).explode().tolist()
    
    return token_list

community_abstracts = {}

for id in range(229):
    community_abstracts[id] = abstracts_for_community_id(id)
# Out:
# Number of authors in community 0: 362
# Number of papers in community 0: 1480
# Number of authors in community 1: 361
# Number of papers in community 1: 968
# Number of authors in community 2: 98
# Number of papers in community 2: 195
# Number of authors in community 3: 3
# Number of papers in community 3: 4
# Number of authors in community 4: 318
# Number of papers in community 4: 790
# Number of authors in community 5: 843
# Number of papers in community 5: 2722
# Number of authors in community 6: 494
# Number of papers in community 6: 1706
# Number of authors in community 7: 355
# Number of papers in community 7: 772
# Number of authors in community 8: 32
# Number of papers in community 8: 32
# Number of authors in community 9: 5
# Number of papers in community 9: 5
# Number of authors in community 10: 262
# Number of papers in community 10: 461
# Number of authors in community 11: 10
# Number of papers in community 11: 7
# Number of authors in community 12: 8
# Number of papers in community 12: 2
# Number of authors in community 13: 3
# Number of authors in community 181: 91
# Number of papers in community 181: 94
# Number of authors in community 182: 3
# Number of papers in community 182: 1
# Number of authors in community 183: 9
# Number of papers in community 183: 5
# Number of authors in community 184: 7
# Number of papers in community 184: 1
# Number of authors in community 185: 5
# Number of papers in community 185: 3
# Number of authors in community 186: 9
# Number of papers in community 186: 6
# Number of authors in community 187: 14
# Number of papers in community 187: 5
# Number of authors in community 188: 2
# Number of papers in community 188: 1
# Number of authors in community 189: 19
# Number of papers in community 189: 3
# Number of authors in community 190: 1043
# Number of papers in community 190: 3142
# Number of authors in community 191: 5
# Number of papers in community 191: 5
# Number of authors in community 192: 2
# Number of papers in community 192: 1
# Number of authors in community 193: 9
# Number of papers in community 193: 1
# Number of authors in community 194: 19
# Number of papers in community 194: 3
# Number of authors in community 195: 16
# Number of papers in community 195: 4
# Number of authors in community 196: 5
# Number of papers in community 196: 1
# Number of authors in community 197: 4
# Number of papers in community 197: 1
# Number of authors in community 198: 22
# Number of papers in community 198: 36
# Number of authors in community 199: 7
# Number of papers in community 199: 1
# Number of authors in community 200: 8
# Number of papers in community 200: 2
# Number of authors in community 201: 31
# Number of papers in community 201: 39
# Number of authors in community 202: 9
# Number of papers in community 202: 18
# Number of authors in community 203: 122
# Number of papers in community 203: 188
# Number of authors in community 204: 4
# Number of papers in community 204: 1
# Number of authors in community 205: 9
# Number of papers in community 205: 12
# Number of authors in community 206: 215
# Number of papers in community 206: 341
# Number of authors in community 207: 44
# Number of papers in community 207: 25
# Number of authors in community 208: 9
# Number of papers in community 208: 4
# Number of authors in community 209: 7
# Number of papers in community 209: 5
# Number of authors in community 210: 4
# Number of papers in community 210: 1
# Number of authors in community 211: 20
# Number of papers in community 211: 36
# Number of authors in community 212: 6
# Number of papers in community 212: 3
# Number of authors in community 213: 107
# Number of papers in community 213: 215
# Number of authors in community 214: 3
# Number of papers in community 214: 7
# Number of authors in community 215: 5
# Number of papers in community 215: 1
# Number of authors in community 216: 40
# Number of papers in community 216: 62
# Number of authors in community 217: 4
# Number of papers in community 217: 2
# Number of authors in community 218: 17
# Number of papers in community 218: 6
# Number of authors in community 219: 3
# Number of papers in community 219: 2
# Number of authors in community 220: 2
# Number of papers in community 220: 1
# Number of authors in community 221: 2
# Number of papers in community 221: 1
# Number of authors in community 222: 23
# Number of papers in community 222: 12
# Number of authors in community 223: 238
# Number of papers in community 223: 310
# Number of authors in community 224: 6
# Number of papers in community 224: 1
# Number of authors in community 225: 7
# Number of papers in community 225: 1
# Number of authors in community 226: 281
# Number of papers in community 226: 587
# Number of authors in community 227: 100
# Number of papers in community 227: 107
# Number of authors in community 228: 23
# Number of papers in community 228: 11

# %% [markdown]
# ### __Top 5 communities__

# %%
asc = {k: v for k, v in sorted(social_compute_louvain_communities_size.items(), key=lambda item: item[1])}
id_list = list(asc.keys())[-5:]

print(id_list)
# Out:
# [151, 54, 5, 190, 85]

# %%
from collections import Counter
def TF_calculate(id_list):
    tf_id = {}
    for i in id_list:
        tokens = community_abstracts[i]
        denom = len(tokens)
        # Count occurrences
        term_counts = Counter(tokens)

        # Get the terms in a fixed order
        terms = list(term_counts.keys())

        counts_array = np.array([term_counts[t] for t in terms])
      
        tf_array = np.log(1 + counts_array)
       
        tf_dictionary = {}
        for term, tf in zip(terms, tf_array):
            tf_dictionary[term] = tf
        tf_id[i] = tf_dictionary
    return tf_id

TF_top_5 = TF_calculate(id_list)

# %%
for id in id_list:
    top_terms = dict(
        sorted(TF_top_5[id].items(), key=lambda item: item[1], reverse=True)[:5]
    )
    print(f"These are the top 5 terms for Community {id} {top_terms}")
# Out:
# These are the top 5 terms for Community 151 {'online': np.float64(6.725033642166843), 'social': np.float64(6.499787040655854), 'users': np.float64(6.434546518787453), 'information': np.float64(6.137727054086234), 'data': np.float64(6.133398042996649)}
# These are the top 5 terms for Community 54 {'users': np.float64(6.665683717782408), 'data': np.float64(6.580639137284949), 'information': np.float64(6.529418838262226), 'social': np.float64(6.505784060128229), 'using': np.float64(6.169610732491456)}
# These are the top 5 terms for Community 5 {'study': np.float64(7.309212365692763), 'social': np.float64(7.306531398939505), 'group': np.float64(6.81783057145415), 'studies': np.float64(6.784457062637643), 'participants': np.float64(6.745236349484363)}
# These are the top 5 terms for Community 190 {'learning': np.float64(7.741967899820685), 'model': np.float64(7.455298485683291), 'image': np.float64(7.45298232946546), 'propose': np.float64(7.443078374348516), 'representation': np.float64(7.3310603052186325)}
# These are the top 5 terms for Community 85 {'models': np.float64(7.555905093611346), 'learning': np.float64(7.430707082545968), 'model': np.float64(7.397561535524052), 'data': np.float64(7.384610383176974), 'tasks': np.float64(7.193685818395112)}

# %% [markdown]
# ### IDF

# %%
from collections import defaultdict

N = 229
doc_freq = defaultdict(int)

# Populate doc_freq
for cid in range(N):
    unique_words = set(community_abstracts[cid])
    for word in unique_words:
        doc_freq[word] += 1


idf_dict_all = {
    word: np.log(N / (1 + doc_freq[word])) + 1
    for word in doc_freq
}

# %% [markdown]
# ### __Top 9 Communities__

# %%
asc = {k: v for k, v in sorted(social_compute_louvain_communities_size.items(), key=lambda item: item[1])}
top_9_id_list = list(asc.keys())[-9:]

print(top_9_id_list)
# Out:
# [20, 62, 47, 6, 151, 54, 5, 190, 85]

# %%
TF_top_9 = TF_calculate(top_9_id_list)

# %%
for id in top_9_id_list:
    top_terms = dict(
        sorted(TF_top_9[id].items(), key=lambda item: item[1], reverse=True)[:10]
    )
    print(f"TF, top 10 terms for Community {id} {top_terms}")
# Out:
# TF, top 10 terms for Community 20 {'networks': np.float64(6.054439346269371), 'model': np.float64(5.730099782973574), 'network': np.float64(5.673323267171493), 'information': np.float64(5.62040086571715), 'find': np.float64(5.497168225293202), 'different': np.float64(5.497168225293202), 'study': np.float64(5.480638923341991), 'results': np.float64(5.476463551931511), 'analysis': np.float64(5.3230099791384085), 'financial': np.float64(5.298317366548036)}
# TF, top 10 terms for Community 62 {'networks': np.float64(6.126869184114185), 'different': np.float64(5.676753802268282), 'study': np.float64(5.6240175061873385), 'network': np.float64(5.602118820879701), 'results': np.float64(5.598421958998375), 'social': np.float64(5.568344503761097), 'cooperation': np.float64(5.564520407322694), 'model': np.float64(5.318119993844216), 'information': np.float64(5.293304824724492), 'systems': np.float64(5.288267030694535)}
# TF, top 10 terms for Community 47 {'information': np.float64(6.161207321695077), 'people': np.float64(6.131226489483141), 'results': np.float64(6.056784013228625), 'study': np.float64(6.025865973825314), 'social': np.float64(6.0112671744041615), 'decision': np.float64(5.857933154483459), 'participants': np.float64(5.855071922202427), 'misinformation': np.float64(5.786897381366708), 'different': np.float64(5.638354669333745), 'models': np.float64(5.58724865840025)}
# TF, top 10 terms for Community 6 {'agents': np.float64(6.612041034833092), 'model': np.float64(6.156978985585555), 'show': np.float64(6.124683390894205), 'results': np.float64(6.111467339502679), 'learning': np.float64(6.068425588244111), 'information': np.float64(6.061456918928017), 'problem': np.float64(6.003887067106539), 'social': np.float64(5.921578419643816), 'study': np.float64(5.8289456176102075), 'using': np.float64(5.823045895483019)}
# TF, top 10 terms for Community 151 {'online': np.float64(6.725033642166843), 'social': np.float64(6.499787040655854), 'users': np.float64(6.434546518787453), 'information': np.float64(6.137727054086234), 'data': np.float64(6.133398042996649), 'study': np.float64(6.126869184114185), 'research': np.float64(6.013715156042802), 'work': np.float64(5.973809611869261), 'communities': np.float64(5.942799375126701), 'results': np.float64(5.937536205082426)}
# TF, top 10 terms for Community 54 {'users': np.float64(6.665683717782408), 'data': np.float64(6.580639137284949), 'information': np.float64(6.529418838262226), 'social': np.float64(6.505784060128229), 'using': np.float64(6.169610732491456), 'study': np.float64(6.163314804034641), 'results': np.float64(6.159095388491933), 'different': np.float64(6.150602768446279), 'networks': np.float64(6.102558594613569), 'model': np.float64(6.09807428216624)}
# TF, top 10 terms for Community 5 {'study': np.float64(7.309212365692763), 'social': np.float64(7.306531398939505), 'group': np.float64(6.81783057145415), 'studies': np.float64(6.784457062637643), 'participants': np.float64(6.745236349484363), 'people': np.float64(6.733401891837359), 'identity': np.float64(6.733401891837359), 'research': np.float64(6.668228248417403), 'results': np.float64(6.648984550024776), 'groups': np.float64(6.530877627725885)}
# TF, top 10 terms for Community 190 {'learning': np.float64(7.741967899820685), 'model': np.float64(7.455298485683291), 'image': np.float64(7.45298232946546), 'propose': np.float64(7.443078374348516), 'representation': np.float64(7.3310603052186325), 'proposed': np.float64(7.299797366758161), 'methods': np.float64(7.298445101508147), 'information': np.float64(7.234898420314831), 'data': np.float64(7.215239978730097), 'results': np.float64(7.149916836132109)}
# TF, top 10 terms for Community 85 {'models': np.float64(7.555905093611346), 'learning': np.float64(7.430707082545968), 'model': np.float64(7.397561535524052), 'data': np.float64(7.384610383176974), 'tasks': np.float64(7.193685818395112), 'using': np.float64(7.1693500166706), 'task': np.float64(7.151485463904735), 'information': np.float64(7.1049654482698426), 'results': np.float64(7.078341579557671), 'language': np.float64(7.078341579557671)}

# %%
TFIDF = {
    cid: dict(sorted(
        {term: tf * idf_dict_all.get(term, 0) 
         for term, tf in TF_top_9[cid].items()}.items(),
        key=lambda x: x[1], reverse=True
    ))
    for cid in top_9_id_list
}

# %%
top_9_id_dict = {}
for id in top_9_id_list:
    G = G_social_compute
    top_terms = dict(
        sorted(TFIDF[id].items(), key=lambda item: item[1], reverse=True)[:10]
    )
    authors_in_community = [
        node for node in G.nodes if G.nodes[node]["community"] == id
    ]
    authors_sorted_by_degree = sorted(
    authors_in_community,
    key=lambda node: G.nodes[node]["degree"],
    reverse=True
    )
    top3_authors = authors_sorted_by_degree[:3] 
    top3_author_names = [G.nodes[node]["display_name"] for node in top3_authors]

    top_9_id_dict[id] = {
        "term": top_terms,
        "authors": top3_author_names
    }

    print(f"TF-IDF, top 10 terms for Community {id} {top_terms} \n Top 3 authors {top3_author_names} \n")
# Out:
# TF-IDF, top 10 terms for Community 20 {'itn': np.float64(17.777676654223107), 'percolation': np.float64(14.943066127979472), 'deltat': np.float64(13.765297231203363), 'gvcs': np.float64(13.765297231203363), 'stocks': np.float64(13.590932263893908), 'unsubstantiated': np.float64(13.320450915469033), 'liquidliquid': np.float64(13.257249607869108), 'zipf': np.float64(13.257249607869108), 'grains': np.float64(12.971444638995308), 'interbank': np.float64(12.946396288295583)}
#  Top 3 authors ['Luı́s A. Nunes Amaral', 'H. Eugene Stanley', 'Guido Caldarelli']
#
# TF-IDF, top 10 terms for Community 62 {'soliton': np.float64(16.90277227164589), 'multiplex': np.float64(15.191566278201863), 'freight': np.float64(13.667975425900252), 'cooperators': np.float64(13.640125600338258), 'catania': np.float64(13.257249607869108), 'masterworker': np.float64(13.218162012643596), 'finitetime': np.float64(13.064403503132086), 'defectors': np.float64(13.009108123531796), 'cooperation': np.float64(12.746019648525605), 'crowdshipping': np.float64(12.613332089120583)}
#  Top 3 authors ['Yamir Moreno', 'Ángel Sánchez', 'Vito Latora']
#
# TF-IDF, top 10 terms for Community 47 {'wmc': np.float64(16.040996752442584), 'inoculation': np.float64(15.839070343681346), 'soep': np.float64(15.717983295710638), 'numeracy': np.float64(15.633005473238997), 'misinformation': np.float64(14.95087994059815), 'gambles': np.float64(14.91206693271349), 'hindsight': np.float64(14.11129868085644), 'affectrich': np.float64(13.765297231203363), 'affectpoor': np.float64(13.765297231203363), 'gri': np.float64(13.765297231203363)}
#  Top 3 authors ['Stephan Lewandowsky', 'Ralph Hertwig', 'Daniel G. Goldstein']
#
# TF-IDF, top 10 terms for Community 6 {'coalitional': np.float64(16.205120213987268), 'auctions': np.float64(16.056742939457273), 'aisb': np.float64(15.98256035583581), 'vegetation': np.float64(15.839070343681346), 'auction': np.float64(15.764360019190034), 'negotiation': np.float64(15.74364783087039), 'bidders': np.float64(15.657444661399621), 'kidney': np.float64(15.411088484486068), 'defender': np.float64(15.263933928914131), 'strategyproof': np.float64(15.06222291180913)}
#  Top 3 authors ['David C. Parkes', 'Iyad Rahwan', 'Esteban Moro']
#
# TF-IDF, top 10 terms for Community 151 {'teens': np.float64(21.443972323470746), 'pol': np.float64(18.98438543267896), 'transactive': np.float64(16.97705672523543), 'attestation': np.float64(16.592395342472482), 'chans': np.float64(15.42045044518433), 'sinophobic': np.float64(15.42045044518433), 'oss': np.float64(14.939417286453198), 'autism': np.float64(14.88767830744914), 'teen': np.float64(14.588942307716662), 'harassment': np.float64(14.563081501133375)}
#  Top 3 authors ['Munmun De Choudhury', 'Diyi Yang', 'Éric Gilbert']
#
# TF-IDF, top 10 terms for Community 54 {'apos': np.float64(17.744360484555266), 'lowcredibility': np.float64(15.601813123018852), 'bioeconomy': np.float64(15.149706062827908), 'eip': np.float64(14.300439349703206), 'lte': np.float64(14.20481012446668), 'offloading': np.float64(13.765793045519937), 'pcgan': np.float64(13.684286235183981), 'twitterers': np.float64(13.684286235183981), 'verticals': np.float64(13.668687442143193), 'bots': np.float64(13.668081103621732)}
#  Top 3 authors ['Ingmar Weber', 'Filippo Menczer', 'Daniele Quercia']
#
# TF-IDF, top 10 terms for Community 5 {'mori': np.float64(22.666188239505036), 'sdo': np.float64(20.831412179117883), 'progroup': np.float64(19.118466702035622), 'ingroup': np.float64(17.919489751137096), 'intergroup': np.float64(17.349941671166658), 'psychopathy': np.float64(17.20343739241848), 'ambivalence': np.float64(17.088120212120916), 'illusory': np.float64(16.97705672523543), 'alexithymia': np.float64(16.885538668833345), 'workingclass': np.float64(16.566529839707812)}
#  Top 3 authors ['Hazel Rose Markus', 'Nick Haslam', 'Matthew J. Hornsey']
#
# TF-IDF, top 10 terms for Community 190 {'vqa': np.float64(21.861462748769508), 'reid': np.float64(21.175735170037928), 'captioning': np.float64(20.14052123175678), 'crossmodal': np.float64(19.22707774958735), 'person_reid': np.float64(18.872710349183), 'reidentification': np.float64(18.585665209117714), 'hne': np.float64(18.478197518583386), 'scene_text': np.float64(18.470453779686334), 'resnet': np.float64(18.364421289662733), 'cnns': np.float64(18.069755598468475)}
#  Top 3 authors ['Jiebo Luo', 'Chunhua Shen', 'Maosong Sun']
#
# TF-IDF, top 10 terms for Community 85 {'qa': np.float64(17.512834791228542), 'ksubgraph': np.float64(17.4773088540363), 'vqa': np.float64(17.35012233376065), 'rl': np.float64(17.272049635417797), 'ips': np.float64(17.197225265995495), 'ibm_almaden': np.float64(17.17305568426644), 'coreference': np.float64(16.914297945547137), 'bleu': np.float64(16.914297945547137), 'parsing': np.float64(16.8193266396351), 'densest': np.float64(16.728205652372875)}
#  Top 3 authors ['Michael S. Bernstein', 'Dan Jurafsky', 'Jon Kleinberg']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 3, figsize=(18, 12))
axes = axes.flatten()

for i,id in enumerate(top_9_id_list):
    ax = axes[i]

    items = TFIDF[id].items()
    authors = top_9_id_dict[id]["authors"]

    terms_dict = {
        word: float(score)
        for word, score in items   
        if score > 0
    }

   # Create a nicer word cloud
    wordcloud = WordCloud(
        width=800,
        height=400,
        background_color='white',
        colormap='plasma',          
        contour_width=1,
        contour_color='black',
        max_words=500
    ).generate_from_frequencies(terms_dict)
    
    # Plot
    ax.imshow(wordcloud, interpolation='bilinear')
    ax.axis('off')
    
    # Format authors nicely (shorten if needed)
    authors_str = ", ".join(authors[:3])
    
    # Stylish title
    ax.set_title(
        f"Community {id}",
        fontsize=14,
        fontweight='bold',
        pad=10
    )
    
    # Subtitle (authors)
    ax.text(
        0.5, -0.1,
        f"Top authors: {authors_str}",
        ha='center',
        va='top',
        transform=ax.transAxes,
        fontsize=10,
        style='italic'
    )

# Remove empty subplots if <9 communities
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
